# %%
import PipelineERVs as PE
reload(PE)
import pandas as pd

# %%
tab = pd.read_csv("/ifs/projects/katherineb/ERVS_test/envs2_results.tsv", sep="\t")
tab['target_start'] = tab['target_start'].astype(int)
tab['target_end'] = tab['target_end'].astype(int)
D = dict()
with open("/ifs/projects/katherineb/ERVS_test/envs_merged.bed") as infile:
    for line in infile:
        line = line.strip().split("\t")
        if line[0] not in D:
            D[line[0]] = []
        D[line[0]].append((int(line[1]), int(line[2])))

# %%
results = pd.DataFrame()
for chromosome in D:
    subtab = tab[(tab['target_id'] == chromosome)]
    for pos_pair in D[chromosome]:
        overlappers = subtab[((subtab['target_start'] >= pos_pair[0]) &
                              (subtab['target_end'] <= pos_pair[1]))]
        scores = overlappers['score'].astype(int)
        best = scores[scores == max(scores)]
        result = overlappers.ix[best.index]
        result['final_target_start'] = pos_pair[0]
        result['final_target_end'] = pos_pair[1]
        cnames = result.columns
        results.ix[result.index, cnames] = result

# %%
result
# Out:
#      Unnamed: 0                              query_id  query_start  query_end  \
# 126         101  RD114_Retrovirus_NC_009889_gamma_env          344        563
#
#     query_strand target_id  target_start  target_end target_strand  score  \
# 126            .     chr14     106654344   106655019             -    308
#
#                                                details  length  \
# 126  M|37|111|G|0|3|M|119|357|G|0|3|M|14|42|G|0|12|...     675
#
#      final_target_start  final_target_end
# 126           106654329         106655019

# %%
cnames = ["query_id", "query_start", "query_end", "query_strand", "target_id", "target_start", "target_end",
          "target_strand", "score", "details"]
df = pd.DataFrame(columns=cnames)

# %%
with open("/ifs/projects/katherineb/ERVS_test/raw_exonerate_output/envs_chr21.tsv") as infile:
    for line in infile:
        line = line.split(": ")
        if line[0] == "vulgar":
            segs = line[1].split(" ")
            for i in range(9):
                df.ix[segs[0], cnames[i]] = segs[i]
            rest = "|".join(line[9:])
            df.ix[segs[0], cnames[9]] = rest

# %%
    with open(infile) as infile:
        for line in infile:
            line = line.strip().split(":")
# Out:
# ['-- completed exonerate analysis\n']

# %%
df['target_start'] = df['target_start'].astype(int)

# %%
df['target_end'] = df['target_end'].astype(int)

# %%
    outs = ['/ifs/projects/katherineb/ERVS_test/raw_exonerate_output/envs2_chr14.tsv', '/ifs/projects/katherineb/ERVS_test/raw_exonerate_output/envs2_chr21.tsv']
    cnames = ["query_id", "query_start", "query_end", "query_strand",
              "target_id", "target_start", "target_end",
              "target_strand", "score", "details"]
    j = 0
    bigdf = pd.DataFrame(columns=cnames)
    
    for out in outs:
        smalldf = pd.DataFrame(columns=cnames)
        with open(out) as infile:
            for line in infile:
                line = line.split(": ")
                if line[0] == "vulgar":
                    segs = line[1].split(" ")
                    for i in range(9):
                        smalldf.ix[str(j), cnames[i]] = segs[i]
                    rest = "|".join(segs[9:])
                    smalldf.ix[str(j), cnames[9]] = rest
                    j += 1
        smalldf = smalldf.sort(['target_start'])
        bigdf = bigdf.append(smalldf)

# %%
bigdf['target_start'] = bigdf['target_start'].astype(int)
bigdf['target_end'] = bigdf['target_end'].astype(int)

# %%
bigdf['Length'] = abs(bigdf['target_end'] - bigdf['target_start'])

# %%
bigdf  = bigdf[bigdf['details'].str.contains("I") == False]

# %%
bigdf[bigdf['Length'] > 200]
# Out:
#                                               query_id query_start query_end  \
# 33     Reticuloendotheliosis_Virus_NC_006934_gamma_env         324       562
# 65       Squirrel_monkey_retrovirus_NC_001514_beta_env         320       552
# 52   Possum_Endogenous_Retrovirus_TvERV_AF284693_be...         331       553
# 0                 RD114_Retrovirus_NC_009889_gamma_env         322       561
# 16                        Simian_ERV_JN134185_beta_env         323       546
# 80                          Baboon_ERV_D10032_beta_env         320       556
# 166      Squirrel_monkey_retrovirus_NC_001514_beta_env         353       505
# 101               RD114_Retrovirus_NC_009889_gamma_env         344       563
# 116                       Simian_ERV_JN134185_beta_env         345       569
# 129                         Baboon_ERV_D10032_beta_env         342       561
# 142    Reticuloendotheliosis_Virus_NC_006934_gamma_env         362       575
# 154  Possum_Endogenous_Retrovirus_TvERV_AF284693_be...         355       555
# 76       Squirrel_monkey_retrovirus_NC_001514_beta_env         393       484
# 42     Reticuloendotheliosis_Virus_NC_006934_gamma_env         402       494
# 123                       Simian_ERV_JN134185_beta_env         449       545
# 108               RD114_Retrovirus_NC_009889_gamma_env         447       545
# 135                         Baboon_ERV_D10032_beta_env         445       543
# 147    Reticuloendotheliosis_Virus_NC_006934_gamma_env         465       563
# 160  Possum_Endogenous_Retrovirus_TvERV_AF284693_be...         458       555
# 150    Reticuloendotheliosis_Virus_NC_006934_gamma_env         341       430
# 107               RD114_Retrovirus_NC_009889_gamma_env         322       412
# 121                       Simian_ERV_JN134185_beta_env         319       413
# 134                         Baboon_ERV_D10032_beta_env         316       410
# 7                 RD114_Retrovirus_NC_009889_gamma_env         417       540
# 23                        Simian_ERV_JN134185_beta_env         418       552
# 87                          Baboon_ERV_D10032_beta_env         415       538
# 8                 RD114_Retrovirus_NC_009889_gamma_env         465       545
# 24                        Simian_ERV_JN134185_beta_env         466       551
# 40     Reticuloendotheliosis_Virus_NC_006934_gamma_env         483       565
# 58   Possum_Endogenous_Retrovirus_TvERV_AF284693_be...         476       555
# ..                                                 ...         ...       ...
# 51   Possum_Endogenous_Retrovirus_TvERV_AF284693_be...         329       555
# 66       Squirrel_monkey_retrovirus_NC_001514_beta_env         326       559
# 192               RD114_Retrovirus_NC_009889_gamma_env         446       545
# 195  Possum_Endogenous_Retrovirus_TvERV_AF284693_be...         457       555
# 197    Reticuloendotheliosis_Virus_NC_006934_gamma_env         464       563
# 199                         Baboon_ERV_D10032_beta_env         444       543
# 202                       Simian_ERV_JN134185_beta_env         447       544
# 205      Squirrel_monkey_retrovirus_NC_001514_beta_env         454       558
# 176                         Baboon_ERV_D10032_beta_env         307       537
# 184               RD114_Retrovirus_NC_009889_gamma_env         309       539
# 187  Possum_Endogenous_Retrovirus_TvERV_AF284693_be...         346       542
# 174      Squirrel_monkey_retrovirus_NC_001514_beta_env         344       538
# 181    Reticuloendotheliosis_Virus_NC_006934_gamma_env         354       548
# 179                       Simian_ERV_JN134185_beta_env         338       538
# 190      Mouse_mammary_tumour_virus_NC_001503_beta_env         395       521
# 175      Squirrel_monkey_retrovirus_NC_001514_beta_env         447       530
# 177                         Baboon_ERV_D10032_beta_env         437       550
# 180                       Simian_ERV_JN134185_beta_env         440       544
# 182    Reticuloendotheliosis_Virus_NC_006934_gamma_env         457       565
# 185               RD114_Retrovirus_NC_009889_gamma_env         439       552
# 188  Possum_Endogenous_Retrovirus_TvERV_AF284693_be...         450       554
# 191               RD114_Retrovirus_NC_009889_gamma_env         374       534
# 194  Possum_Endogenous_Retrovirus_TvERV_AF284693_be...         385       546
# 196    Reticuloendotheliosis_Virus_NC_006934_gamma_env         392       555
# 198                         Baboon_ERV_D10032_beta_env         372       533
# 201                       Simian_ERV_JN134185_beta_env         375       535
# 204      Squirrel_monkey_retrovirus_NC_001514_beta_env         382       507
# 193               RD114_Retrovirus_NC_009889_gamma_env         434       542
# 200                         Baboon_ERV_D10032_beta_env         422       540
# 203                       Simian_ERV_JN134185_beta_env         425       547
#
#     query_strand target_id  target_start  target_end target_strand score  \
# 33             .     chr14     102713608   102714329             +   380
# 65             .     chr14     102713632   102714329             +   392
# 52             .     chr14     102713656   102714323             +   371
# 0              .     chr14     102713662   102714389             +   427
# 16             .     chr14     102713662   102714332             +   420
# 80             .     chr14     102713662   102714380             +   427
# 166            .     chr14     106655016   106654557             -   269
# 101            .     chr14     106655019   106654344             -   308
# 116            .     chr14     106655019   106654329             -   265
# 129            .     chr14     106655019   106654344             -   291
# 142            .     chr14     106655019   106654362             -   293
# 154            .     chr14     106655019   106654401             -   302
# 76             .     chr14      23204451    23204730             +   120
# 42             .     chr14      23204454    23204730             +   118
# 123            .     chr14      25895687    25895396             -   115
# 108            .     chr14      25895690    25895393             -   139
# 135            .     chr14      25895690    25895393             -   140
# 147            .     chr14      25895690    25895393             -   138
# 160            .     chr14      25895690    25895396             -   125
# 150            .     chr14      25930325    25930067             -   102
# 107            .     chr14      25930328    25930067             -   161
# 121            .     chr14      25930343    25930067             -   179
# 134            .     chr14      25930343    25930067             -   172
# 7              .     chr14      25930484    25930848             +   208
# 23             .     chr14      25930484    25930881             +   193
# 87             .     chr14      25930484    25930848             +   199
# 8              .     chr14      26728928    26729165             +   169
# 24             .     chr14      26728928    26729180             +   154
# 40             .     chr14      26728928    26729171             +   164
# 58             .     chr14      26728928    26729162             +   166
# ..           ...       ...           ...         ...           ...   ...
# 51             .     chr14      99457874    99458555             +   383
# 66             .     chr14      99457874    99458576             +   389
# 192            .     chr21      17765417    17765117             -   183
# 195            .     chr21      17765417    17765120             -   179
# 197            .     chr21      17765417    17765117             -   186
# 199            .     chr21      17765417    17765117             -   187
# 202            .     chr21      17765417    17765123             -   171
# 205            .     chr21      17765417    17765102             -   159
# 176            .     chr21      18677078    18677760             +   381
# 184            .     chr21      18677078    18677760             +   366
# 187            .     chr21      18677160    18677736             +   339
# 174            .     chr21      18677163    18677733             +   361
# 181            .     chr21      18677163    18677733             +   319
# 179            .     chr21      18677166    18677754             +   347
# 190            .     chr21      19934759    19934375             -   134
# 175            .     chr21      28233036    28233286             +   177
# 177            .     chr21      28233036    28233373             +   232
# 180            .     chr21      28233036    28233346             +   194
# 182            .     chr21      28233036    28233358             +   204
# 185            .     chr21      28233036    28233373             +   225
# 197            M|39|117|G|0|6|M|15|45|G|1|0|M|44|132\n     300
# 199             M|49|147|G|0|6|M|5|15|G|1|0|M|44|132\n     300
# 202            M|43|129|G|0|6|M|11|33|G|1|0|M|42|126\n     294
# 205                          M|55|165|G|0|3|M|49|147\n     315
# 176  M|28|84|F|0|4|M|34|102|G|2|0|M|123|369|G|2|0|M...     682
# 184  M|33|99|F|0|4|M|25|75|G|1|0|M|7|21|G|1|0|M|120...     682
# 187            M|33|99|G|2|0|M|126|378|G|2|0|M|33|99\n     576
# 174            M|32|96|G|2|0|M|126|378|G|2|0|M|32|96\n     570
# 181           M|32|96|G|2|0|M|124|372|G|2|0|M|34|102\n     570
# 179          M|34|102|G|2|0|M|121|363|G|2|0|M|41|123\n     588
# 190             M|15|45|G|0|3|M|31|93|G|0|3|M|80|240\n     384
# 175                           M|63|189|F|0|1|M|20|60\n     250
# 177            M|51|153|F|0|1|M|34|102|G|1|0|M|27|81\n     337
# 180            M|51|153|F|0|1|M|34|102|G|1|0|M|18|54\n     310
# 182            M|51|153|F|0|1|M|34|102|G|1|0|M|22|66\n     322
# 185             M|53|159|F|0|1|M|32|96|G|1|0|M|27|81\n     337
# 188             M|54|162|F|0|1|M|31|93|G|1|0|M|18|54\n     310
# 191             M|122|366|G|2|0|M|1|3|F|0|1|M|35|105\n     475
# 194             M|120|360|F|0|1|M|3|9|G|2|0|M|36|108\n     478
# 196           M|112|336|F|0|1|M|11|33|G|2|0|M|38|114\n     484
# 198             M|122|366|G|2|0|M|1|3|F|0|1|M|36|108\n     478
# 201             M|120|360|G|2|0|M|3|9|F|0|1|M|35|105\n     475
# 204                                        M|125|375\n     375
# 193  M|24|72|F|0|1|M|20|60|G|0|6|M|33|99|G|0|9|M|13...     337
# 200  M|34|102|F|0|1|M|28|84|G|0|6|M|25|75|G|0|9|M|1...     367
# 203  M|34|102|F|0|1|M|28|84|G|0|6|M|25|75|G|0|9|M|1...     379
#
# [159 rows x 11 columns]

# %%
r1 = bigdf.ix['33']

# %%
r2 = bigdf.ix['65']

# %%
def isOverlapping(region1, region2):
    r1 = (min(region1['target_start'], region1['target_end']),
               max(region1['target_start'], region1['target_end']))
    r2 = (min(region2['target_start'], region2['target_end']),
               max(region2['target_start'], region2['target_end']))
    case1 = r1[0] < r2[0]

# %%
isOverlapping(r1, r2)
# Out:
# (102713608, 102714329)
# (102713632, 102714329)

# %%
df2 = pd.read_csv('/ifs/projects/katherineb/ERVS_test/raw_exonerate_output/envs2.tsv', sep="\t", index_col=0)

# %%
df2 = df2[((df2.Length>200) & (df2.details.str.contains("I") == False))]

# %%
df2[cnames]
# Out:
#                                               query_id  query_start  \
# 76       Squirrel_monkey_retrovirus_NC_001514_beta_env          393
# 42     Reticuloendotheliosis_Virus_NC_006934_gamma_env          402
# 123                       Simian_ERV_JN134185_beta_env          449
# 147    Reticuloendotheliosis_Virus_NC_006934_gamma_env          465
# 108               RD114_Retrovirus_NC_009889_gamma_env          447
# 160  Possum_Endogenous_Retrovirus_TvERV_AF284693_be...          458
# 135                         Baboon_ERV_D10032_beta_env          445
# 150    Reticuloendotheliosis_Virus_NC_006934_gamma_env          341
# 107               RD114_Retrovirus_NC_009889_gamma_env          322
# 134                         Baboon_ERV_D10032_beta_env          316
# 121                       Simian_ERV_JN134185_beta_env          319
# 7                 RD114_Retrovirus_NC_009889_gamma_env          417
# 23                        Simian_ERV_JN134185_beta_env          418
# 87                          Baboon_ERV_D10032_beta_env          415
# 8                 RD114_Retrovirus_NC_009889_gamma_env          465
# 24                        Simian_ERV_JN134185_beta_env          466
# 77       Squirrel_monkey_retrovirus_NC_001514_beta_env          473
# 88                          Baboon_ERV_D10032_beta_env          463
# 40     Reticuloendotheliosis_Virus_NC_006934_gamma_env          483
# 58   Possum_Endogenous_Retrovirus_TvERV_AF284693_be...          476
# 131                         Baboon_ERV_D10032_beta_env          421
# 157  Possum_Endogenous_Retrovirus_TvERV_AF284693_be...          434
# 143    Reticuloendotheliosis_Virus_NC_006934_gamma_env          441
# 167      Squirrel_monkey_retrovirus_NC_001514_beta_env          431
# 119                       Simian_ERV_JN134185_beta_env          424
# 104               RD114_Retrovirus_NC_009889_gamma_env          423
# 128                         Baboon_ERV_D10032_beta_env          409
# 103               RD114_Retrovirus_NC_009889_gamma_env          411
# 156  Possum_Endogenous_Retrovirus_TvERV_AF284693_be...          422
# 168      Squirrel_monkey_retrovirus_NC_001514_beta_env          419
# ..                                                 ...          ...
# 129                         Baboon_ERV_D10032_beta_env          342
# 101               RD114_Retrovirus_NC_009889_gamma_env          344
# 205      Squirrel_monkey_retrovirus_NC_001514_beta_env          454
# 202                       Simian_ERV_JN134185_beta_env          447
# 199                         Baboon_ERV_D10032_beta_env          444
# 197    Reticuloendotheliosis_Virus_NC_006934_gamma_env          464
# 195  Possum_Endogenous_Retrovirus_TvERV_AF284693_be...          457
# 192               RD114_Retrovirus_NC_009889_gamma_env          446
# 176                         Baboon_ERV_D10032_beta_env          307
# 184               RD114_Retrovirus_NC_009889_gamma_env          309
# 187  Possum_Endogenous_Retrovirus_TvERV_AF284693_be...          346
# 174      Squirrel_monkey_retrovirus_NC_001514_beta_env          344
# 181    Reticuloendotheliosis_Virus_NC_006934_gamma_env          354
# 179                       Simian_ERV_JN134185_beta_env          338
# 190      Mouse_mammary_tumour_virus_NC_001503_beta_env          395
# 182    Reticuloendotheliosis_Virus_NC_006934_gamma_env          457
# 185               RD114_Retrovirus_NC_009889_gamma_env          439
# 175      Squirrel_monkey_retrovirus_NC_001514_beta_env          447
# 188  Possum_Endogenous_Retrovirus_TvERV_AF284693_be...          450
# 177                         Baboon_ERV_D10032_beta_env          437
# 180                       Simian_ERV_JN134185_beta_env          440
# 201                       Simian_ERV_JN134185_beta_env          375
# 198                         Baboon_ERV_D10032_beta_env          372
# 196    Reticuloendotheliosis_Virus_NC_006934_gamma_env          392
# 194  Possum_Endogenous_Retrovirus_TvERV_AF284693_be...          385
# 191               RD114_Retrovirus_NC_009889_gamma_env          374
# 204      Squirrel_monkey_retrovirus_NC_001514_beta_env          382
# 193               RD114_Retrovirus_NC_009889_gamma_env          434
# 200                         Baboon_ERV_D10032_beta_env          422
# 203                       Simian_ERV_JN134185_beta_env          425
#
# 198    310               M|122|366|G|2|0|M|1|3|F|0|1|M|36|108
# 196    306             M|112|336|F|0|1|M|11|33|G|2|0|M|38|114
# 194    306               M|120|360|F|0|1|M|3|9|G|2|0|M|36|108
# 191    300               M|122|366|G|2|0|M|1|3|F|0|1|M|35|105
# 204    301                                          M|125|375
# 193    117  M|24|72|F|0|1|M|20|60|G|0|6|M|33|99|G|0|9|M|13...
# 200    119  M|34|102|F|0|1|M|28|84|G|0|6|M|25|75|G|0|9|M|1...
# 203    100  M|34|102|F|0|1|M|28|84|G|0|6|M|25|75|G|0|9|M|1...
#
# [159 rows x 10 columns]

# %%
plus = smalldf[smalldf['target_start'] < smalldf['target_end']]
minus = smalldf[smalldf['target_start'] > smalldf['target_end']]

# %%
tempstart = minus['target_start']
tempend = minus['target_end']

# %%
minus = minus.drop(['target_start', 'target_end'], 1)

# %%
minus['target_start'] = tempend
minus['target_end'] = tempstart

# %%
reload(PE)
x = PE.filterExonerate("/ifs/projects/katherineb/ERVS_test/raw_exonerate_output/envs2_chr21.tsv", 200)

# %%
x['target_start'] = x['target_start'].astype('object')

# %%
x
# Out:
#                                              query_id query_start query_end  \
# 31      Squirrel_monkey_retrovirus_NC_001514_beta_env         454       558
# 25                         Baboon_ERV_D10032_beta_env         444       543
# 23    Reticuloendotheliosis_Virus_NC_006934_gamma_env         464       563
# 18               RD114_Retrovirus_NC_009889_gamma_env         446       545
# 21  Possum_Endogenous_Retrovirus_TvERV_AF284693_be...         457       555
# 28                       Simian_ERV_JN134185_beta_env         447       544
# 2                          Baboon_ERV_D10032_beta_env         307       537
# 10               RD114_Retrovirus_NC_009889_gamma_env         309       539
# 13  Possum_Endogenous_Retrovirus_TvERV_AF284693_be...         346       542
# 0       Squirrel_monkey_retrovirus_NC_001514_beta_env         344       538
# 7     Reticuloendotheliosis_Virus_NC_006934_gamma_env         354       548
# 5                        Simian_ERV_JN134185_beta_env         338       538
# 16      Mouse_mammary_tumour_virus_NC_001503_beta_env         395       521
# 8     Reticuloendotheliosis_Virus_NC_006934_gamma_env         457       565
# 11               RD114_Retrovirus_NC_009889_gamma_env         439       552
# 1       Squirrel_monkey_retrovirus_NC_001514_beta_env         447       530
# 14  Possum_Endogenous_Retrovirus_TvERV_AF284693_be...         450       554
# 3                          Baboon_ERV_D10032_beta_env         437       550
# 6                        Simian_ERV_JN134185_beta_env         440       544
# 22    Reticuloendotheliosis_Virus_NC_006934_gamma_env         392       555
# 24                         Baboon_ERV_D10032_beta_env         372       533
# 20  Possum_Endogenous_Retrovirus_TvERV_AF284693_be...         385       546
# 17               RD114_Retrovirus_NC_009889_gamma_env         374       534
# 27                       Simian_ERV_JN134185_beta_env         375       535
# 30      Squirrel_monkey_retrovirus_NC_001514_beta_env         382       507
# 29                       Simian_ERV_JN134185_beta_env         425       547
# 19               RD114_Retrovirus_NC_009889_gamma_env         434       542
# 26                         Baboon_ERV_D10032_beta_env         422       540
#
#    query_strand target_id target_start  target_end target_strand score  \
# 31            .     chr21     17765102    17765417             -   159
# 25            .     chr21     17765117    17765417             -   187
# 23            .     chr21     17765117    17765417             -   186
